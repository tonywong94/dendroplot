# %%
from yso_postage_stamp import yso_postage_stamp, yso_asgn_structures, get_yso_asgn
import astropy.units as u

# %%
RAs = [84.705292,84.735785,84.719458,84.768284,84.688917,84.802613,84.568865,\
       84.67695,84.561444,84.75514,84.728895,84.726672]*u.deg
DECs = [-69.079003,-69.071474,-69.077081,-69.070499,-69.04761,-69.025504,-69.081416,\
        -69.051177,-69.079705,-69.036991,-69.025066,-69.025835]*u.deg
#postage stamp dimensions
RA_width = 1.0*u.arcmin
DEC_width = 1*u.arcmin

# %%
dir_='/Users/alexgreen/Box/ALMALMC/Dendrograms/YSO_scripts/'
yso_postage_stamp(dir_+'30Dor_12_cycle7.asgn.fits.gz',RAs[0], DECs[0],\
                  RA_width=1.0*u.arcmin, DEC_width=1.0*u.arcmin, slice_=87)

# %%
loc = '/Users/alexgreen/Box/ALMALMC/30 Doradus Cycle 7/12+13CO Cubes/products_250/'
yso_postage_stamp(loc+'30Dor_feather_mosaic_12CO_12meter.image.fits.gz',\
    RAs[3], DECs[3],RA_width=1.0*u.arcmin, DEC_width=1.0*u.arcmin,slice_=87)

# %%
yso_asgn_structures('/Users/alexgreen/Box/dendroplot-master/example/30Dor_12_cycle7.asgn.fits.gz',\
                    RAs[0], DECs[0],'asgn_yso0')
dictionaries = get_yso_asgn('asgn_yso0')
